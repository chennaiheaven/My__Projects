# %% [markdown]
# PROBLEM SET 3 - QUESTION 1

# %%
import pandas as pd  #Step 1. Import the necessary libraries

# %%
#Step 2. Import the dataset from this address.
#Step 3. Assign it to a variable called users
URL = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"
users = pd.read_csv(URL, sep = "|")
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
Step 4. Discover what is the mean age per occupation
users.groupby('occupation').age.mean()
# Out:
#   File "C:\Users\12269\AppData\Local\Temp\ipykernel_52600\3290992165.py", line 1
#     Step 4. Discover what is the mean age per occupation
#          ^
# SyntaxError: invalid syntax

# %%
#Step 5. Discover the Male ratio per occupation
def gender(G):
    if G == 'M':
        return True
    else:
        return False

# %%
users['male'] = users['gender'].apply(gender)

# %%
maleratio = users.groupby('occupation')['male'].sum()
maleratio
# Out:
# occupation
# administrator     43
# artist            15
# doctor             7
# educator          69
# engineer          65
# entertainment     16
# executive         29
# healthcare         5
# homemaker          1
# lawyer            10
# librarian         22
# marketing         16
# none               5
# other             69
# programmer        60
# retired           13
# salesman           9
# scientist         28
# student          136
# technician        26
# writer            26
# Name: male, dtype: int64

# %%
total = users.groupby('occupation').gender.count()
total
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: gender, dtype: int64

# %%
#Step - 5 - sort it from the most to the least
ratio = maleratio/total
SortToDes = ratio.sort_values(ascending = False)
SortToDes
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %%
users.groupby('occupation').age.min()
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64

# %%
users.groupby('occupation').age.max()
# Out:
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# Name: age, dtype: int64

# %%
users.groupby([ 'occupation' , 'gender' ])[ 'age' ].mean ()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
genderwise = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
genderwise
occu_count = users.groupby(['occupation']).count()
occu_count
percentageBygender = genderwise.div(occu_count, level = "occupation") * 100
percentageBygender.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %% [markdown]
# PROBLEM SET 3 - QUESTION 2 Euro Teams

# %%
#Step 1. Import the necessary libraries

import pandas as pd
import numpy as np

# %%
#Step 2. Import the dataset from this address
#Step 3. Assign it to a variable called euro12

euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep = ",")
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
#Step 4. Select only the Goal column
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#Step 5. How many team participated in the Euro2012?
euro12.Team.nunique()
# Out:
# 16

# %%
#Step 6. What is the number of columns in the dataset?
len(euro12.columns)
# Out:
# 35

# %%
#Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#Step 8. Sort the teams by Red Cards
sortbyred = discipline.sort_values(by='Red Cards')
sortbyred
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1

# %%
#Step 8. Sort then to Yellow Cards
sortbyYellow = discipline.sort_values(by='Yellow Cards')
sortbyYellow
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 9                Poland             7          1
# 14               Sweden             7          0
# 0               Croatia             9          0
# 6                Greece             9          1
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0

# %%
#Step 9. Calculate the mean Yellow Cards given per Team
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#Step 10. Filter teams that scored more than 6 goals
euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Step 11. Select the teams that start with G
euro12[euro12.Team.str.startswith("G")]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#Step 12. Select the first 7 columns
euro12.iloc[: ,0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 13. Select all columns except the last 3
euro12.iloc[: ,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 14. Present only the Shooting Accuracy from England, Italy and Russia
euro12.loc[euro12.Team.isin(["England","Italy","Russia"]), ["Shooting Accuracy","Team"]]
# Out:
#    Shooting Accuracy     Team
# 3              50.0%  England
# 7              43.0%    Italy
# 12             22.5%   Russia

# %% [markdown]
# PROBLEM SET 3 - QUESTION 3 HOUSING

# %%
#Step 1. Import the necessary libraries
import random
import pandas as pd
import numpy as np

# %%
#Step 2. Create 3 differents Series, each of length 100, as follows:
#The first a random number from 1 to 4
firstseries = pd.Series(np.random.randint(1,4,100))
firstseries
# Out:
# 0     2
# 1     3
# 2     2
# 3     2
# 4     2
#      ..
# 95    3
# 96    3
# 97    3
# 98    1
# 99    1
# Length: 100, dtype: int32

# %%
#The second a random number from 1 to 3
secondseries = pd.Series(np.random.randint(1,3,100))
secondseries
# Out:
# 0     2
# 1     2
# 2     1
# 3     1
# 4     1
#      ..
# 95    2
# 96    2
# 97    2
# 98    1
# 99    1
# Length: 100, dtype: int32

# %%
#The third a random number from 10,000 to 30,000
thirdseries = pd.Series(np.random.randint(10000,30000,100))
thirdseries
# Out:
# 0     23009
# 1     17016
# 2     18897
# 3     15307
# 4     29926
#       ...
# 95    11177
# 96    19228
# 97    13927
# 98    17324
# 99    16546
# Length: 100, dtype: int32

# %%
#Step 3. Create a DataFrame by joinning the Series by column
DF1 = pd.concat([firstseries, secondseries, thirdseries], axis = 1)
DF1
# Out:
#     0  1      2
# 0   2  2  23009
# 1   3  2  17016
# 2   2  1  18897
# 3   2  1  15307
# 4   2  1  29926
# .. .. ..    ...
# 95  3  2  11177
# 96  3  2  19228
# 97  3  2  13927
# 98  1  1  17324
# 99  1  1  16546
#
# [100 rows x 3 columns]

# %%
#Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
DF1.columns = ['bedrs','bathrs','price_sqr_meter']
DF1
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       2            23009
# 1       3       2            17016
# 2       2       1            18897
# 3       2       1            15307
# 4       2       1            29926
# ..    ...     ...              ...
# 95      3       2            11177
# 96      3       2            19228
# 97      3       2            13927
# 98      1       1            17324
# 99      1       1            16546
#
# [100 rows x 3 columns]

# %%
#Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.concat([firstseries, secondseries, thirdseries], axis = 0)
bigcolumn
# Out:
# 0         2
# 1         3
# 2         2
# 3         2
# 4         2
#       ...
# 95    11177
# 96    19228
# 97    13927
# 98    17324
# 99    16546
# Length: 300, dtype: int32

# %%
#Step 6. Ops it seems it is going only until index 99. Is it true?
#Step 7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn.index = range(0, 300)
bigcolumn
# Out:
# 0          2
# 1          3
# 2          2
# 3          2
# 4          2
#        ...
# 295    11177
# 296    19228
# 297    13927
# 298    17324
# 299    16546
# Length: 300, dtype: int32

# %% [markdown]
# PROBLEM SET 3 - QUESTION 4 WIND STATISTICS

# %%
#Step 1. Import the necessary libraries
import pandas as pd
import datetime

# %%
#Step 2. Import the dataset from the attached file wind.txt
pd.read_csv("wind.csv")
# Out:
#      Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 0     61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 1...
# 1     61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 1...
# 2     61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 1...
# 3     61  1  4 10.58  6.63 11.75  4.58  4.54  2.88  ...
# 4     61  1  5 13.33 13.25 11.42  6.17 10.71  8.21 1...
# ...                                                 ...
# 6569  78 12 27 17.58 16.96 17.62  8.08 13.21 11.67 1...
# 6570  78 12 28 13.21  5.46 13.46  5.00  8.12  9.42 1...
# 6571  78 12 29 14.00 10.29 14.42  8.71  9.71 10.54 1...
# 6572  78 12 30 18.50 14.04 21.29  9.13 12.75  9.71 1...
# 6573  78 12 31 20.33 17.41 27.29  9.59 12.08 10.13 1...
#
# [6574 rows x 1 columns]

# %%
#Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
data = pd.read_csv("wind.csv", sep="\s+")
data["Date"] = pd.to_datetime(data[["Yr", "Mo", "Dy"]].astype(str).agg('-'.join, axis=1))
data = data.drop(columns=["Yr", "Mo", "Dy"])
data.head()
# Out:
#      RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
# 2  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67  12.75
# 3  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88   5.46
# 4  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34  12.92
#
#      MAL       Date
# 0  15.04 2061-01-01
# 1  13.83 2061-01-02
# 2  12.71 2061-01-03
# 3  10.88 2061-01-04
# 4  11.83 2061-01-05

# %%
#Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
data["Date"] = np.where(pd.DatetimeIndex(data["Date"]).year < 2000, data.Date,
data.Date - pd.offsets.DateOffset(years=100))

# %%
#Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
new_df = data.set_index("Date")
new_df.index.astype("datetime64[ns]")
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %%
#Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.
print(new_df.isnull().values.ravel().sum())
# Out:
# 31

# %%
#Step 7. Compute how many non-missing values there are in total.
non_missing_values = new_df.count()
print("Total non-missing values are :", non_missing_values.sum())
# Out:
# Total non-missing values are : 78857

# %%
#Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
windspeeds_mean = new_df.mean()
windspeeds_mean.mean()
# Out:
# 10.227982360836924

# %%
#Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days. A different set of numbers for each location.
def stats(x):
    x = pd.Series(x)
    Min = x.min()
    Max = x.max()
    Mean = x.mean()
    Std = x.std()
    res = [Min, Max, Mean, Std]
    indx = ["Min", "Max", "Mean", "Std"]
    res = pd.Series(res, index=indx)
    return res
loc_stats = new_df.apply(stats)
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# Min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# Max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# Mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# Std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# Min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# Max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# Mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# Std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %%
#Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day. A different set of numbers for each day.
day_stats = new_df.apply(stats, axis=1)
day_stats.head()
# Out:
#              Min    Max       Mean       Std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %%
# Step 11. Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.
Januarydata = new_df[new_df.index.month == 1]
print("January windspeeds:")
print(Januarydata.mean())
# Out:
# January windspeeds:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
#Step 12. Downsample the record to a yearly frequency for each location.
print("Yearly:\n", new_df.resample('A').mean())
# Out:
# Yearly:
#                    RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
#Step 13. Downsample the record to a monthly frequency for each location.
print("Monthly:", new_df.resample('M').mean())
# Out:
# Monthly:                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
#Step 14. Downsample the record to a weekly frequency for each location.
print("Weekly:", new_df.resample('W').mean())
# Out:
# Weekly:                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %%
#Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.
firstyear = new_df[new_df.index.year == 1961]
stats = new_df.resample('W').mean().apply(lambda x: x.describe())
print(stats)
# Out:
#               RPT         VAL         ROS         KIL         SHA         BIR  \
# count  940.000000  940.000000  940.000000  940.000000  939.000000  940.000000
# mean    12.365304   10.647725   11.661255    6.309334   10.455607    7.094787
# std      3.466600    3.372501    2.840361    2.186432    3.146715    2.556633
# min      3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# 25%      9.884286    8.277857    9.613929    4.742857    8.248571    5.211071
# 50%     12.291429   10.486429   11.490000    6.165714   10.254286    6.933571
# 75%     14.547143   12.757857   13.457143    7.584286   12.627143    8.842500
# max     24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
#
#               DUB         CLA         MUL         CLO         BEL         MAL
# count  940.000000  940.000000  940.000000  940.000000  940.000000  940.000000
# mean     9.801271    8.496123    8.496452    8.710639   13.125912   15.597171
# ...

# %% [markdown]
# PROBLEM SET 3 - QUESTION 5

# %%
#Step 1. Import the necessary libraries
import pandas as pd

# %%
#Step 2. Import the dataset from this address.
#Step 3. Assign it to a variable called chipo.
#Step 4. See the first 10 entries
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep = "\t")
chipo[0:10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Step 5. What is the number of observations in the dataset?
len(chipo)
# Out:
# 4622

# %%
#Step 6. What is the number of columns in the dataset?
len(chipo.columns)
# Out:
# 5

# %%
#Step 7. Print the name of all the columns.
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Step 8. How is the dataset indexed?
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Step 9. Which was the most-ordered item?
chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False).index[0]
# Out:
# 'Chicken Bowl'

# %%
#Step 10. For the most-ordered item, how many items were ordered?
chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
#Step 11. What was the most ordered item in the choice_description column?
chipo.groupby(['choice_description']).quantity.sum().sort_values(ascending = False).index[0]
# Out:
# '[Diet Coke]'

# %%
#Step 12. How many items were orderd in total?
chipo.quantity.sum()
# Out:
# 4972

# %%
#Step 13. Turn the item price into a float
def convert_to_float(num):
    return float(num[1:-1])

# %%
#Step 13. Check the item price type
chipo.dtypes.item_price
# Out:
# dtype('O')

# %%
#Step 13. Create a lambda function and change the type of item price
chipo.item_price = chipo.item_price.apply(lambda x: float(x[1:]))
chipo.item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
#Step 13. Check the item price type
chipo.dtypes.item_price
# Out:
# dtype('float64')

# %%
# Step 14. How much was the revenue for the period in the dataset?
revenue = (chipo['quantity'] * chipo['item_price']).sum()

print('Revenue: $' + str(np.round(revenue,2)))
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_52600\741204090.py in <module>
#       2 revenue = (chipo['quantity'] * chipo['item_price']).sum()
#       3
# ----> 4 print('Revenue: $' + str(np.round(revenue,2)))
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~\Documents\BIG DATA ANALYTICS\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in round_(a, decimals, out)
#    3737     around : equivalent function; see for details.
#    3738     """
# -> 3739     return around(a, decimals=decimals, out=out)
#    3740
#    3741
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~\Documents\BIG DATA ANALYTICS\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in around(a, decimals, out)
#    3312
#    3313     """
# -> 3314     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3315
#    3316
#
# ...

# %%
#Step 15. How many orders were made in the period?
first_year = new_df[new_df.index.year == 1961]
stats = new_df.resample('W').mean().apply(lambda x: x.describe())
print(stats)
orders = chipo.order_id.value_counts().count()
orders
# Out:
#               RPT         VAL         ROS         KIL         SHA         BIR  \
# count  940.000000  940.000000  940.000000  940.000000  939.000000  940.000000
# mean    12.365304   10.647725   11.661255    6.309334   10.455607    7.094787
# std      3.466600    3.372501    2.840361    2.186432    3.146715    2.556633
# min      3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# 25%      9.884286    8.277857    9.613929    4.742857    8.248571    5.211071
# 50%     12.291429   10.486429   11.490000    6.165714   10.254286    6.933571
# 75%     14.547143   12.757857   13.457143    7.584286   12.627143    8.842500
# max     24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
#
#               DUB         CLA         MUL         CLO         BEL         MAL
# count  940.000000  940.000000  940.000000  940.000000  940.000000  940.000000
# mean     9.801271    8.496123    8.496452    8.710639   13.125912   15.597171
# ...

# %%
# Step 16. What is the average revenue amount per order?
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Documents\BIG DATA ANALYTICS\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Documents\BIG DATA ANALYTICS\Anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Documents\BIG DATA ANALYTICS\Anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'revenue'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Step 17. How many different items are sold?
chipo.item_name.nunique()
# Out:
# 50

# %% [markdown]
# PROBLEM SET 3 - QUESTION 6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
data.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
plt.figure()
data.plot('Year',y=['Marriages','Divorces'])
plt.ylabel('Values')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# PROBLEM SET 3 - QUESTION 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
data.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
divorcedata = data[data['Year'].apply(lambda x: x in [1900, 1950, 2000])]
marriages = divorcedata['Marriages_per_1000'].values
divorces = divorcedata['Divorces_per_1000'].values

# %%
X = ['1900', '1950', '2000']
xaxis = np.arange(len(X))
plt.bar(xaxis - 0.2, marriages, 0.4, label = 'Marriages')
plt.bar(xaxis + 0.2, divorces, 0.4, label = 'Divorces')
plt.xticks(xaxis, X)
plt.xlabel("Years")
plt.ylabel("Values")
plt.legend()
 
# Show graph
plt.show()

# %% [markdown]
# PROBLEM SET 3 - QUESTION 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('actor_kill_counts.csv')
data.head()
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239

# %%
data = data.sort_values('Count', ascending = True)
Actorname = data['Actor'].values
Kills = data['Count'].values

# %%
plt.barh(Actorname, Kills)
plt.ylabel("Actors")
plt.xlabel("Kill Count")
plt.show()

# %% [markdown]
# PROBLEM SET 3 - QUESTION 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('roman-emperor-reigns.csv')
data.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 4      Nero            13.67                Suicide

# %%
DiedEmperors = data[data['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]
DiedEmperors.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 5     Galba             0.58           Assassinated

# %%
chart = plt.figure(figsize =(10, 7))
colors=['red', 'green']
plt.pie([len(DiedEmperors),len(data) - len(DiedEmperors)], labels = ['Assassinated', 'Other Deaths'],  colors=colors, startangle=90, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# PROBLEM SET 3 - QUESTION 10
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
data.head()
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948

# %%
totalrevenue = data['Total Arcade Revenue (billions)'].values
CSPHD = data['Computer Science Doctorates Awarded (US)'].values

# %%
plt.scatter(totalrevenue, CSPHD)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.xlabel('Total Arcade Revenue')
plt.ylabel('Computer Science Doctorates Awarded (US)')
plt.show()
